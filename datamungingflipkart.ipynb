# %% [markdown]
# <a href="https://colab.research.google.com/github/ShrutiMishra-2002/python-practice/blob/main/datamungingflipkart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/sample_data/flipkart_smartphones.xlsx.csv')
df.head(5)
# Out:
#                                 title       ram     brand  \
# 0        POCO C31 (Royal Blue, 64 GB)  4 GB RAM      POCO
# 1       POCO C31 (Shadow Gray, 64 GB)  4 GB RAM      POCO
# 2   realme C35 (Glowing Green, 64 GB)  4 GB RAM    realme
# 3     OPPO K10 (Black Carbon, 128 GB)  6 GB RAM      OPPO
# 4  MOTOROLA G60 (Soft Silver, 128 GB)  6 GB RAM  MOTOROLA
#
#                                                  url        product_id  \
# 0  https://www.flipkart.com/poco-c31-royal-blue-6...  MOBG73E7GKQK4KZP
# 1  https://www.flipkart.com/poco-c31-shadow-gray-...  MOBG73E7UBFXXMCH
# 2  https://www.flipkart.com/realme-c35-glowing-gr...  MOBGBTHFSKHF8RAU
# 3  https://www.flipkart.com/oppo-k10-black-carbon...  MOBGCFUHMDFSCM9W
# 4  https://www.flipkart.com/motorola-g60-soft-sil...  MOBG9CJ6G5GCFAH4
#
#                   listing_id  \
# 0  LSTMOBG73E7GKQK4KZPR5ICMK
# 1  LSTMOBG73E7UBFXXMCHSM0ZN5
# 2  LSTMOBGBTHFSKHF8RAUQONXWY
# 3  LSTMOBGCFUHMDFSCM9WSL0U8O
# 4  LSTMOBG9CJ6G5GCFAH4CCXVXL
#
# ...

# %%
df.shape
# Out:
# (847, 19)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                        title       ram     brand  \
# 0               POCO C31 (Royal Blue, 64 GB)  4 GB RAM      POCO
# 1              POCO C31 (Shadow Gray, 64 GB)  4 GB RAM      POCO
# 2          realme C35 (Glowing Green, 64 GB)  4 GB RAM    realme
# 3            OPPO K10 (Black Carbon, 128 GB)  6 GB RAM      OPPO
# 4         MOTOROLA G60 (Soft Silver, 128 GB)  6 GB RAM  MOTOROLA
# ..                                       ...       ...       ...
# 842                 OPPO A37f (Black, 16 GB)  2 GB RAM      OPPO
# 843     KARBONN K9 Kavach (Champagne, 16 GB)  2 GB RAM   KARBONN
# 844          OPPO Reno2 (Ocean Blue, 256 GB)  8 GB RAM      OPPO
# 845  SAMSUNG Galaxy A53 (Light Blue, 128 GB)  8 GB RAM   SAMSUNG
# 846                YU Ace (Rose Gold, 16 GB)  2 GB RAM        YU
#
#                                                    url        product_id  \
# 0    https://www.flipkart.com/poco-c31-royal-blue-6...  MOBG73E7GKQK4KZP
# ...

# %%
df.tail(5)
# Out:
#                                        title       ram    brand  \
# 842                 OPPO A37f (Black, 16 GB)  2 GB RAM     OPPO
# 843     KARBONN K9 Kavach (Champagne, 16 GB)  2 GB RAM  KARBONN
# 844          OPPO Reno2 (Ocean Blue, 256 GB)  8 GB RAM     OPPO
# 845  SAMSUNG Galaxy A53 (Light Blue, 128 GB)  8 GB RAM  SAMSUNG
# 846                YU Ace (Rose Gold, 16 GB)  2 GB RAM       YU
#
#                                                    url        product_id  \
# 842  https://www.flipkart.com/oppo-a37f-black-16-gb...  MOBEWMAUFU9AFWUH
# 843  https://www.flipkart.com/karbonn-k9-kavach-cha...  MOBFYJC5CM5MHRMJ
# 844  https://www.flipkart.com/oppo-reno2-ocean-blue...  MOBFJY8YRNGGZPVD
# 845  https://www.flipkart.com/samsung-galaxy-a53-li...  MOBGCFVYUHHUJFNY
# 846  https://www.flipkart.com/yu-ace-rose-gold-16-g...  MOBF8HV9DHJJYXGH
#
#                     listing_id  \
# 842  LSTMOBEWMAUFU9AFWUHHNTLTZ
# 843  LSTMOBFYJC5CM5MHRMJQGWAWV
# 844  LSTMOBFJY8YRNGGZPVDUGG2GJ
# ...

# %%
df.isnull()
# Out:
#      title    ram  brand    url  product_id  listing_id  highlights  \
# 0    False  False  False  False       False       False       False
# 1    False  False  False  False       False       False       False
# 2    False  False  False  False       False       False       False
# 3    False  False  False  False       False       False       False
# 4    False  False  False  False       False       False       False
# ..     ...    ...    ...    ...         ...         ...         ...
# 842  False  False  False  False       False       False       False
# 843  False  False  False  False       False       False       False
# 844  False  False  False  False       False       False       False
# 845  False  False  False  False       False       False       False
# 846  False  False  False  False       False       False       False
#
#      availability  selling_price  original_price  currency  avg_rating  \
# 0           False          False           False     False       False
# ...

# %%
df.isnull().sum()
# Out:
# title                  0
# ram                  101
# brand                  0
# url                    0
# product_id             0
# listing_id             0
# highlights             0
# availability           0
# selling_price          0
# original_price         0
# currency               0
# avg_rating             0
# ratings_count          0
# reviews_count          0
# one_stars_count        0
# two_stars_count        0
# three_stars_count      0
# four_stars_count       0
# five_stars_count       0
# dtype: int64

# %%
df2=df.fillna(value=0)
df2
# Out:
#                                        title       ram     brand  \
# 0               POCO C31 (Royal Blue, 64 GB)  4 GB RAM      POCO
# 1              POCO C31 (Shadow Gray, 64 GB)  4 GB RAM      POCO
# 2          realme C35 (Glowing Green, 64 GB)  4 GB RAM    realme
# 3            OPPO K10 (Black Carbon, 128 GB)  6 GB RAM      OPPO
# 4         MOTOROLA G60 (Soft Silver, 128 GB)  6 GB RAM  MOTOROLA
# ..                                       ...       ...       ...
# 842                 OPPO A37f (Black, 16 GB)  2 GB RAM      OPPO
# 843     KARBONN K9 Kavach (Champagne, 16 GB)  2 GB RAM   KARBONN
# 844          OPPO Reno2 (Ocean Blue, 256 GB)  8 GB RAM      OPPO
# 845  SAMSUNG Galaxy A53 (Light Blue, 128 GB)  8 GB RAM   SAMSUNG
# 846                YU Ace (Rose Gold, 16 GB)  2 GB RAM        YU
#
#                                                    url        product_id  \
# 0    https://www.flipkart.com/poco-c31-royal-blue-6...  MOBG73E7GKQK4KZP
# ...

# %%
df2=df.fillna(value="check")
df2
# Out:
#                                        title       ram     brand  \
# 0               POCO C31 (Royal Blue, 64 GB)  4 GB RAM      POCO
# 1              POCO C31 (Shadow Gray, 64 GB)  4 GB RAM      POCO
# 2          realme C35 (Glowing Green, 64 GB)  4 GB RAM    realme
# 3            OPPO K10 (Black Carbon, 128 GB)  6 GB RAM      OPPO
# 4         MOTOROLA G60 (Soft Silver, 128 GB)  6 GB RAM  MOTOROLA
# ..                                       ...       ...       ...
# 842                 OPPO A37f (Black, 16 GB)  2 GB RAM      OPPO
# 843     KARBONN K9 Kavach (Champagne, 16 GB)  2 GB RAM   KARBONN
# 844          OPPO Reno2 (Ocean Blue, 256 GB)  8 GB RAM      OPPO
# 845  SAMSUNG Galaxy A53 (Light Blue, 128 GB)  8 GB RAM   SAMSUNG
# 846                YU Ace (Rose Gold, 16 GB)  2 GB RAM        YU
#
#                                                    url        product_id  \
# 0    https://www.flipkart.com/poco-c31-royal-blue-6...  MOBG73E7GKQK4KZP
# ...

# %%
df2.isnull().sum()
# Out:
# title                0
# ram                  0
# brand                0
# url                  0
# product_id           0
# listing_id           0
# highlights           0
# availability         0
# selling_price        0
# original_price       0
# currency             0
# avg_rating           0
# ratings_count        0
# reviews_count        0
# one_stars_count      0
# two_stars_count      0
# three_stars_count    0
# four_stars_count     0
# five_stars_count     0
# dtype: int64

# %%
df3=df.fillna(method='pad')
df3
# Out:
#                                        title       ram     brand  \
# 0               POCO C31 (Royal Blue, 64 GB)  4 GB RAM      POCO
# 1              POCO C31 (Shadow Gray, 64 GB)  4 GB RAM      POCO
# 2          realme C35 (Glowing Green, 64 GB)  4 GB RAM    realme
# 3            OPPO K10 (Black Carbon, 128 GB)  6 GB RAM      OPPO
# 4         MOTOROLA G60 (Soft Silver, 128 GB)  6 GB RAM  MOTOROLA
# ..                                       ...       ...       ...
# 842                 OPPO A37f (Black, 16 GB)  2 GB RAM      OPPO
# 843     KARBONN K9 Kavach (Champagne, 16 GB)  2 GB RAM   KARBONN
# 844          OPPO Reno2 (Ocean Blue, 256 GB)  8 GB RAM      OPPO
# 845  SAMSUNG Galaxy A53 (Light Blue, 128 GB)  8 GB RAM   SAMSUNG
# 846                YU Ace (Rose Gold, 16 GB)  2 GB RAM        YU
#
#                                                    url        product_id  \
# 0    https://www.flipkart.com/poco-c31-royal-blue-6...  MOBG73E7GKQK4KZP
# ...

# %%
df4=df.fillna(method='bfill')
df4
# Out:
#                                        title       ram     brand  \
# 0               POCO C31 (Royal Blue, 64 GB)  4 GB RAM      POCO
# 1              POCO C31 (Shadow Gray, 64 GB)  4 GB RAM      POCO
# 2          realme C35 (Glowing Green, 64 GB)  4 GB RAM    realme
# 3            OPPO K10 (Black Carbon, 128 GB)  6 GB RAM      OPPO
# 4         MOTOROLA G60 (Soft Silver, 128 GB)  6 GB RAM  MOTOROLA
# ..                                       ...       ...       ...
# 842                 OPPO A37f (Black, 16 GB)  2 GB RAM      OPPO
# 843     KARBONN K9 Kavach (Champagne, 16 GB)  2 GB RAM   KARBONN
# 844          OPPO Reno2 (Ocean Blue, 256 GB)  8 GB RAM      OPPO
# 845  SAMSUNG Galaxy A53 (Light Blue, 128 GB)  8 GB RAM   SAMSUNG
# 846                YU Ace (Rose Gold, 16 GB)  2 GB RAM        YU
#
#                                                    url        product_id  \
# 0    https://www.flipkart.com/poco-c31-royal-blue-6...  MOBG73E7GKQK4KZP
# ...

# %%
df5=df.fillna(method='pad' , axis=1)
df5
# Out:
#                                        title       ram     brand  \
# 0               POCO C31 (Royal Blue, 64 GB)  4 GB RAM      POCO
# 1              POCO C31 (Shadow Gray, 64 GB)  4 GB RAM      POCO
# 2          realme C35 (Glowing Green, 64 GB)  4 GB RAM    realme
# 3            OPPO K10 (Black Carbon, 128 GB)  6 GB RAM      OPPO
# 4         MOTOROLA G60 (Soft Silver, 128 GB)  6 GB RAM  MOTOROLA
# ..                                       ...       ...       ...
# 842                 OPPO A37f (Black, 16 GB)  2 GB RAM      OPPO
# 843     KARBONN K9 Kavach (Champagne, 16 GB)  2 GB RAM   KARBONN
# 844          OPPO Reno2 (Ocean Blue, 256 GB)  8 GB RAM      OPPO
# 845  SAMSUNG Galaxy A53 (Light Blue, 128 GB)  8 GB RAM   SAMSUNG
# 846                YU Ace (Rose Gold, 16 GB)  2 GB RAM        YU
#
#                                                    url        product_id  \
# 0    https://www.flipkart.com/poco-c31-royal-blue-6...  MOBG73E7GKQK4KZP
# ...

# %%
df6=df.fillna(method='bfill',axis=1)
df6
# Out:
#                                        title       ram     brand  \
# 0               POCO C31 (Royal Blue, 64 GB)  4 GB RAM      POCO
# 1              POCO C31 (Shadow Gray, 64 GB)  4 GB RAM      POCO
# 2          realme C35 (Glowing Green, 64 GB)  4 GB RAM    realme
# 3            OPPO K10 (Black Carbon, 128 GB)  6 GB RAM      OPPO
# 4         MOTOROLA G60 (Soft Silver, 128 GB)  6 GB RAM  MOTOROLA
# ..                                       ...       ...       ...
# 842                 OPPO A37f (Black, 16 GB)  2 GB RAM      OPPO
# 843     KARBONN K9 Kavach (Champagne, 16 GB)  2 GB RAM   KARBONN
# 844          OPPO Reno2 (Ocean Blue, 256 GB)  8 GB RAM      OPPO
# 845  SAMSUNG Galaxy A53 (Light Blue, 128 GB)  8 GB RAM   SAMSUNG
# 846                YU Ace (Rose Gold, 16 GB)  2 GB RAM        YU
#
#                                                    url        product_id  \
# 0    https://www.flipkart.com/poco-c31-royal-blue-6...  MOBG73E7GKQK4KZP
# ...

# %%
df7=df.fillna(value=df['selling_price'].mean())
df7
# Out:
#                                        title       ram     brand  \
# 0               POCO C31 (Royal Blue, 64 GB)  4 GB RAM      POCO
# 1              POCO C31 (Shadow Gray, 64 GB)  4 GB RAM      POCO
# 2          realme C35 (Glowing Green, 64 GB)  4 GB RAM    realme
# 3            OPPO K10 (Black Carbon, 128 GB)  6 GB RAM      OPPO
# 4         MOTOROLA G60 (Soft Silver, 128 GB)  6 GB RAM  MOTOROLA
# ..                                       ...       ...       ...
# 842                 OPPO A37f (Black, 16 GB)  2 GB RAM      OPPO
# 843     KARBONN K9 Kavach (Champagne, 16 GB)  2 GB RAM   KARBONN
# 844          OPPO Reno2 (Ocean Blue, 256 GB)  8 GB RAM      OPPO
# 845  SAMSUNG Galaxy A53 (Light Blue, 128 GB)  8 GB RAM   SAMSUNG
# 846                YU Ace (Rose Gold, 16 GB)  2 GB RAM        YU
#
#                                                    url        product_id  \
# 0    https://www.flipkart.com/poco-c31-royal-blue-6...  MOBG73E7GKQK4KZP
# ...

# %%
df8=df.fillna(value=df['selling_price'].min())
df8
# Out:
#                                        title       ram     brand  \
# 0               POCO C31 (Royal Blue, 64 GB)  4 GB RAM      POCO
# 1              POCO C31 (Shadow Gray, 64 GB)  4 GB RAM      POCO
# 2          realme C35 (Glowing Green, 64 GB)  4 GB RAM    realme
# 3            OPPO K10 (Black Carbon, 128 GB)  6 GB RAM      OPPO
# 4         MOTOROLA G60 (Soft Silver, 128 GB)  6 GB RAM  MOTOROLA
# ..                                       ...       ...       ...
# 842                 OPPO A37f (Black, 16 GB)  2 GB RAM      OPPO
# 843     KARBONN K9 Kavach (Champagne, 16 GB)  2 GB RAM   KARBONN
# 844          OPPO Reno2 (Ocean Blue, 256 GB)  8 GB RAM      OPPO
# 845  SAMSUNG Galaxy A53 (Light Blue, 128 GB)  8 GB RAM   SAMSUNG
# 846                YU Ace (Rose Gold, 16 GB)  2 GB RAM        YU
#
#                                                    url        product_id  \
# 0    https://www.flipkart.com/poco-c31-royal-blue-6...  MOBG73E7GKQK4KZP
# ...

# %%
df9=df.fillna(value=df['selling_price'].max())
df9
# Out:
#                                        title       ram     brand  \
# 0               POCO C31 (Royal Blue, 64 GB)  4 GB RAM      POCO
# 1              POCO C31 (Shadow Gray, 64 GB)  4 GB RAM      POCO
# 2          realme C35 (Glowing Green, 64 GB)  4 GB RAM    realme
# 3            OPPO K10 (Black Carbon, 128 GB)  6 GB RAM      OPPO
# 4         MOTOROLA G60 (Soft Silver, 128 GB)  6 GB RAM  MOTOROLA
# ..                                       ...       ...       ...
# 842                 OPPO A37f (Black, 16 GB)  2 GB RAM      OPPO
# 843     KARBONN K9 Kavach (Champagne, 16 GB)  2 GB RAM   KARBONN
# 844          OPPO Reno2 (Ocean Blue, 256 GB)  8 GB RAM      OPPO
# 845  SAMSUNG Galaxy A53 (Light Blue, 128 GB)  8 GB RAM   SAMSUNG
# 846                YU Ace (Rose Gold, 16 GB)  2 GB RAM        YU
#
#                                                    url        product_id  \
# 0    https://www.flipkart.com/poco-c31-royal-blue-6...  MOBG73E7GKQK4KZP
# ...

# %%
df9=df.dropna()
df9
# Out:
#                                        title       ram     brand  \
# 0               POCO C31 (Royal Blue, 64 GB)  4 GB RAM      POCO
# 1              POCO C31 (Shadow Gray, 64 GB)  4 GB RAM      POCO
# 2          realme C35 (Glowing Green, 64 GB)  4 GB RAM    realme
# 3            OPPO K10 (Black Carbon, 128 GB)  6 GB RAM      OPPO
# 4         MOTOROLA G60 (Soft Silver, 128 GB)  6 GB RAM  MOTOROLA
# ..                                       ...       ...       ...
# 842                 OPPO A37f (Black, 16 GB)  2 GB RAM      OPPO
# 843     KARBONN K9 Kavach (Champagne, 16 GB)  2 GB RAM   KARBONN
# 844          OPPO Reno2 (Ocean Blue, 256 GB)  8 GB RAM      OPPO
# 845  SAMSUNG Galaxy A53 (Light Blue, 128 GB)  8 GB RAM   SAMSUNG
# 846                YU Ace (Rose Gold, 16 GB)  2 GB RAM        YU
#
#                                                    url        product_id  \
# 0    https://www.flipkart.com/poco-c31-royal-blue-6...  MOBG73E7GKQK4KZP
# ...

# %%
df12=df.replace(to_replace=11999, value=800)
df12
# Out:
#                                        title       ram     brand  \
# 0               POCO C31 (Royal Blue, 64 GB)  4 GB RAM      POCO
# 1              POCO C31 (Shadow Gray, 64 GB)  4 GB RAM      POCO
# 2          realme C35 (Glowing Green, 64 GB)  4 GB RAM    realme
# 3            OPPO K10 (Black Carbon, 128 GB)  6 GB RAM      OPPO
# 4         MOTOROLA G60 (Soft Silver, 128 GB)  6 GB RAM  MOTOROLA
# ..                                       ...       ...       ...
# 842                 OPPO A37f (Black, 16 GB)  2 GB RAM      OPPO
# 843     KARBONN K9 Kavach (Champagne, 16 GB)  2 GB RAM   KARBONN
# 844          OPPO Reno2 (Ocean Blue, 256 GB)  8 GB RAM      OPPO
# 845  SAMSUNG Galaxy A53 (Light Blue, 128 GB)  8 GB RAM   SAMSUNG
# 846                YU Ace (Rose Gold, 16 GB)  2 GB RAM        YU
#
#                                                    url        product_id  \
# 0    https://www.flipkart.com/poco-c31-royal-blue-6...  MOBG73E7GKQK4KZP
# ...

# %%
df13=df['selling_price']=df['selling_price'].interpolate(method='linear')
df13
# Out:
# 0       8999
# 1       8999
# 2      11999
# 3      14990
# 4      16999
#        ...
# 842     9990
# 843     7490
# 844    39990
# 845    35999
# 846     7999
# Name: selling_price, Length: 847, dtype: int64
